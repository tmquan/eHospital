# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("data.csv", 
                 sep=';',
                 encoding = "utf-8", )
# Out:
# /Users/tmquan/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18642876 entries, 0 to 18642875
# Data columns (total 21 columns):
# mã_bệnh_nhân          int64
# mã_bệnh_Án            int64
# ngày_vào_viện         object
# ngày_ra_viện          object
# mã_Điều_trị           int64
# quá_trình_bệnh_lý     object
# icd10_ra_viện         object
# chẩn_Đoán_ra_viện     object
# xử_trí_khám_bệnh      int64
# kết_quả_Điều_trị      int64
# mẫu_bệnh_phẩm         int64
# ngày_thực_hiện        object
# icd10_chỉ_Định        object
# chẩn_Đoán_chỉ_Định    object
# tên_chỉ_Định          object
# số_lượng              float64
# mã_báo_cáo            object
# tên_kết_quả           object
# kết_quả               object
# giới_hạn_dưới         object
# giới_hạn_trên         object
# dtypes: float64(1), int64(6), object(14)
# memory usage: 2.9+ GB

# %%
df.memory_usage(deep=True)
# Out:
# Index                         80
# mã_bệnh_nhân           149143008
# mã_bệnh_Án             149143008
# ngày_vào_viện         1416858576
# ngày_ra_viện          1416858576
# mã_Điều_trị            149143008
# quá_trình_bệnh_lý     2326269233
# icd10_ra_viện         1098511592
# chẩn_Đoán_ra_viện     3727045901
# xử_trí_khám_bệnh       149143008
# kết_quả_Điều_trị       149143008
# mẫu_bệnh_phẩm          149143008
# ngày_thực_hiện        1417636390
# icd10_chỉ_Định        1100646223
# chẩn_Đoán_chỉ_Định    3443052687
# tên_chỉ_Định          2760751447
# số_lượng               149143008
# mã_báo_cáo             939726285
# tên_kết_quả           1036184349
# kết_quả                862918682
# giới_hạn_dưới          750622268
# giới_hạn_trên          744350582
# dtype: int64

# %%
df.dtypes
# Out:
# mã_bệnh_nhân            int64
# mã_bệnh_Án              int64
# ngày_vào_viện          object
# ngày_ra_viện           object
# mã_Điều_trị             int64
# quá_trình_bệnh_lý      object
# icd10_ra_viện          object
# chẩn_Đoán_ra_viện      object
# xử_trí_khám_bệnh        int64
# kết_quả_Điều_trị        int64
# mẫu_bệnh_phẩm           int64
# ngày_thực_hiện         object
# icd10_chỉ_Định         object
# chẩn_Đoán_chỉ_Định     object
# tên_chỉ_Định           object
# số_lượng              float64
# mã_báo_cáo             object
# tên_kết_quả            object
# kết_quả                object
# giới_hạn_dưới          object
# giới_hạn_trên          object
# dtype: object

# %%
df.head()
# Out:
#    mã_bệnh_nhân  mã_bệnh_Án        ngày_vào_viện         ngày_ra_viện  \
# 0             1     1786275  2018-07-17 07:33:45  0001-01-01 00:00:00
# 1             3     1690101  2018-05-31 15:17:43  0001-01-01 00:00:00
# 2             3     1690101  2018-05-31 15:17:43  0001-01-01 00:00:00
# 3             3     1778770  2018-07-13 10:02:13  0001-01-01 00:00:00
# 4             3     1778770  2018-07-13 10:02:13  0001-01-01 00:00:00
#
#    mã_Điều_trị quá_trình_bệnh_lý icd10_ra_viện     chẩn_Đoán_ra_viện  \
# 0      2096601               NaN           NaN                   NaN
# 1      1984478               NaN           B00  Nhiễm Herpes simplex
# 2      1984537               NaN           NaN                   NaN
# 3      2087886               NaN           NaN                   NaN
# 4      2087886               NaN           NaN                   NaN
#
#    xử_trí_khám_bệnh  kết_quả_Điều_trị  ...       ngày_thực_hiện  \
# ...

# %%
da = df.iloc[0:100000]

# %%
da.to_csv("data_100k.csv", 
          sep=';',
          encoding = "utf-8", )
