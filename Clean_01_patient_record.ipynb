# %%
import glob
from natsort import natsorted

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
pd.set_option('display.max_colwidth', -1)

from IPython.display import display

# %%
### 
df = pd.read_csv('data/1.patient.csv',
                         sep=';', 
                         error_bad_lines=False, 
                         warn_bad_lines=False)
#Sample for running
# df = df.sample(1000)

selected  = [
#     'hosobenhanid',
    'patientid',
#     'chandoanravien_code',
#     'chandoanravien',
    'patientname',
#     'patientcode',
    'gioitinhcode',
    'nghenghiepcode',
    'noilamviec',
    'hc_thon', 
    'hc_xacode', 
    'hc_huyencode',
    'hc_tinhcode',
    'hc_quocgiacode',
#     'hc_xaname',
#     'hc_huyenname',
#     'hc_tinhname',
#     'hc_quocgianame',
]

renamed  = {
#     'hosobenhanid':'record_id',
    'patientid':'patient_id',
#     'chandoanravien_code':'diagnosis_icd10_out',
#     'chandoanravien':'diagnosis_vn_out',
    'patientname':'patient_name',
#     'patientcode',
    'gioitinhcode':'patient_gender',
    'nghenghiepcode':'patient_occupation',
    'noilamviec':'patient_workplace',
    'hc_thon':'patient_street', 
    'hc_xacode':'patient_ward_code', 
    'hc_huyencode':'patient_district_code',
    'hc_tinhcode':'patient_city_code',
    'hc_quocgiacode':'patient_country_code',
}


# Select desired feature
df = df[selected]
df.rename(columns=renamed, inplace=True)

# Remove dot in icd10
# df['diagnosis_icd10_out'] = df['diagnosis_icd10_out'].astype('str').apply(lambda x: x.split('.')[0])

# object string to categorical
df[df.select_dtypes(['object']).columns] = df.select_dtypes(['object']).apply(lambda x: x.astype('category'))
# display(df.dtypes)
# display(df['diagnosis_icd10_out'].cat.codes)



# Remove NAN
df.dropna(inplace=True)

# categorical to numerical
# df['diagnosis_icd10_out'] = df['diagnosis_icd10_out'].cat.codes
# display(df.dtypes)
# df[df.select_dtypes(['category']).columns] = df.select_dtypes(['category']).apply(lambda x: x.cat.codes)
# display(df.dtypes)



# Normalize
# df = (df-df.mean())/df.std()


display(df.columns)
display(len(df.columns))
display(df)

df.to_csv('Clean_01_patient_id.csv')
display(df.dtypes)
# Out:
# Index(['patient_id', 'patient_name', 'patient_gender', 'patient_occupation',
#        'patient_workplace', 'patient_street', 'patient_ward_code',
#        'patient_district_code', 'patient_city_code', 'patient_country_code'],
#       dtype='object')
# 10
#       patient_id           patient_name  patient_gender patient_occupation  \
# 19     3960       TRẦN VĂN THẤN          1.0             13
# 32     455226     ĐỖ NGUYỄN HÀ ANH       2.0             2
# 111    489439     NGUYỄN THỊ THU LÀNH    2.0             13
# 161    128675     VÕ THỊ NGỌC ÁNH        2.0             13
# 163    52         LƯU VĂN ĐOÀN           1.0             13
# 195    163190     VŨ MINH TRÍ            1.0             13
# 210    495498     HÀ VĂN LONG            1.0             13
# 225    599108     NGUYỄN THỊ DUYÊN       2.0             13
# 227    114381     NGÔ VĂN LỢI            1.0             13
# 260    163191     NGUYỄN HOÀNG LANG      1.0             13
# 263    599109     NGUYỄN THANH TÒNG      1.0             13
# 296    599110     TRẦN VŨ LINH           1.0             13
# 325    588126     VÕ THỊ NHỆN            2.0             3
# 352    239678     ĐÀM THỊ DUYÊN          2.0             13
# 383    599111     TRẦN HOÀNG HẢI         1.0             13
# 446    89351      NGUYỄN HỮU ĐỨC         1.0             13
# 468    577034     PHAN THỊ BẠCH TUYẾT    2.0             4
# 482    91585      VÕ THỊ NHƯ THỦY        2.0             4
# 487    5523       PHẠM NGỌC THU HÀ       2.0             13
# 501    128678     NGUYỄN THỊ CẨM TÚ      2.0             13
# 524    142222     TẰNG KIM PHỤNG         2.0             13
# 563    384187     NGUYỄN THỊ TUYẾT       2.0             4
# 572    303666     TRẦN VĂN DẶNG          1.0             99
# 601    485847     TRẦN VĂN QUANG         1.0             99
# 626    489440     NGUYỄN THỊ MAI PHƯƠNG  2.0             13
# 631    577764     NGUYỄN VĂN BINH        1.0             3
# 632    163195     NGUYỄN HOÀNG MINH      1.0             13
# 679    610        HỒ VÕ NHẬT TRÂM        2.0             13
# 798    578182     PHẠM THỊ HỒNG HOA      2.0             99
# 805    12759      VÕ THỊ ÁNH TUYẾT       2.0             13
# ...      ...                   ...       ...             ..
# 98211  115506     NGUYỄN THỊ KIM THẢO    2.0             13
# 98215  582014     NGUYỄN THỊ HOÀNG OANH  2.0             13
# 98218  123191     TÔ MINH HÒA            1.0             13
# 98229  105440     TRẦN THỊ HẢO           2.0             13
# 98232  105430     NGUYỄN HOÀNG ÂU        1.0             13
# 98267  458092     NGUYỄN VĂN HÀO         1.0             13
# 98271  585639     NGUYỄN THỊ SƯƠNG       2.0             03
# 98300  324679     TRẦN XUÂN TRƯỜNG       1.0             01
# 98305  136675     HUỲNH CÔNG VĂN         1.0             13
# 98309  121142     PHẠM ÂN NGỌC           1.0             13
# 98342  123425     NGUYỄN THỊ TUYỀN       2.0             13
# 98352  497902     NGÔ THỊ MỸ             2.0             5
# 98358  123195     PHAN THỊ CẨM HỒNG      2.0             13
# 98372  174168     NGUYỄN PHƯƠNG NHI      2.0             2
# 98378  27001      HUỲNH THỊ GÁI          2.0             4
# 98389  54383      NGUYỄN THỊ CẨM         2.0             4
# 98406  124810     PHẠM THỊ PHƯƠNG HẰNG   2.0             15
# 98432  61571      PHAN THỊ ẢNH           2.0             4
# 98440  558104     TRẦN THỊ NGUYỆT        2.0             13
# 98446  124508     NGUYỄN THỊ LAN         2.0             4
# 98449  296788     TẠ THỊ TUYẾT MAI       2.0             4
# 98451  225827     LÊ THỊ LUYẾN           2.0             13
# 98452  591025     NGUYỄN TRƯỜNG THỊNH    1.0             2
# 98460  123429     PHAN NHẬT DUY          1.0             13
# 98464  129334     NGUYỄN VĂN VĂN         1.0             13
# 98473  124509     NGUYỄN THỊ THANH THÚY  2.0             4
# 98480  598469     LÊ VĂN TÙNG            1.0             99
# 98501  585645     THẠCH HOÀNG BẢO MINH   1.0             1
# 98509  587247     HUỲNH THỊ NHƠN         2.0             3
# 98512  169204     NGUYỄN THỊ THẢO        2.0             13
#
#                                                              patient_workplace  \
# 19     ấp Đình, Tân Phú Trung, Củ Chi
# 32     Tổ 1 ấp 1, Xã Phước Vĩnh An, Huyện Củ Chi, Thành phố Hồ Chí Minh_1.2
# 111    CÔNG TY TNHH LOGISTIK UNICORP VIỆT NAM
# 161    BỆNH VIỆN ĐA KHOA XUYÊN Á
# 163    CTY  CP TẬP ĐOÀN MAI LINH
# 195    CTY TNHH MTV DV CÔNG ÍCH QUẬN 12
# 210    CTY TNHH VINA FOODS KYOEI
# 225    CTY TNHH IN NANU SG
# 227    CTY TNHH MTV KIDO
# 260    CTY TNHH MTV DV CÔNG ÍCH QUẬN 12
# 263    CTY TNHH IN NANU SG
# 296    CTY TNHH IN NANU SG
# 325    Hòa Bình 1, Xã Hiệp Hòa, Huyện Đức Hòa, Tỉnh Long An
# 352    CTY CP UNIBEN
# 383    CTY TNHH IN NANU SG
# 446    CTY CP UNIBEN
# 468    thuận hòa 1-hòa khánh nam-đức hòa-long an_0171-40014333
# 482    CTY CP UNIBEN
# 487    Lớp 12A4,Trường THPT Tân Thông Hội
# 501    BỆNH VIỆN ĐA KHOA XUYÊN Á
# 524    CTY DV Y TẾ H&H
# 563    CTY TNHH Song Tân
# 572    Đức Hòa Thượng, Đức Hòa, Long An
# 601    Tổ 12, ấp Thượng, Xã Tân Thông Hội, Huyện Củ Chi, Thành phố Hồ Chí Minh
# 626    CÔNG TY TNHH LOGISTIK UNICORP VIỆT NAM
# 631    Xã Tân Thạnh Đông-Huyện Củ Chi_TM
# 632    CTY TNHH MTV DV CÔNG ÍCH QUẬN 12
# 679    học sinh
# 798    Xã Lộc Thái - Lộc Ninh - Bình Phước
# 805    B530,CTY TNHH MM QUÃNG VIỆT
# ...                             ...
# 98211  cong ty TNHH CARIMAX SAI GON
# 98215  Lạc Chỉ, Xã Hòa Mỹ Đông, Huyện Tây Hòa, Tỉnh Phú Yên
# 98218  LIÊN ĐOÀN LAO ĐỘNG Q.12
# 98229  THANH TRA XD TP.HCM - H. HÓC MÔN
# 98232  THANH TRA XD TP.HCM - H. HÓC MÔN
# 98267  Tân An Hội, Củ Chi, TP. Hồ Chí Minh
# 98271  44/2B Đông Lân 1, Xã Bà Điểm, Huyện Hóc Môn, Thành phố Hồ Chí Minh_8
# 98300  701351920170174
# 98305  CTY CP KỸ NGHỆ ĐÔ THÀNH
# 98309  CTY DỊCH VỤ Y TẾ H&H
# 98342  CTY TNHH SX-TM TOBA
# 98352  Phước Tân 2, Xã Phan, Huyện Dương Minh Châu, Tỉnh Tây Ninh
# 98358  LIÊN ĐOÀN LAO ĐỘNG Q.12
# 98372  Trường THPT Phú Hòa_10A6
# 98378  CTY TNHH DỆT MAY HOA SEN
# 98389  CTY TNHH VINA DUKE
# 98406  TRƯỜNG MẦM NON HƯỚNG DƯƠNG
# 98432  CTY CP VIỆT NAM MỘC BÀI
# 98440  KP 8, Thị trấn Bến Lức, Huyện Bến Lức, Tỉnh Long An
# 98446  CTY TNHH DAEWOONG VIỆT NAM
# 98449  Tân Trung, Long Tân, Ngã Năm, Sóc Trăng
# 98451  CƠ SỞ XÃ HỘI NHỊ XUÂN
# 98452  290/61 tổ 3 ấp 1, Xã Nhị Bình, Huyện Hóc Môn, Thành phố Hồ Chí Minh_9/3
# 98460  CTY TNHH SX-TM TOBA
# 98464  CTY TNHH MTV THOÁT NƯỚC ĐÔ THỊ TP.HCM
# 98473  CTY TNHH SBGEAR VINA
# 98480  Bốn Phú, Xã Trung An, Huyện Củ Chi, Thành phố Hồ Chí Minh
# 98501  701350120180165
# 98509  Tân Qui Hạ, Tân Phú, Đức Hòa, Long An (Vợ BB)
# 98512  FA3-LN9-FA3MLN6149,Cty TNHH Hansae VN
#
#                                patient_street  patient_ward_code  \
# 19     ẤP ĐÌNH                                 20.0
# 32     Tổ 1, Ấp 1                              14.0
# 111    CÔNG TY TNHH LOGISTIK UNICORP VIỆT NAM  0.0
# 161    BỆNH VIỆN ĐA KHOA XUYÊN Á               0.0
# 163    CTY  CP TẬP ĐOÀN MAI LINH               21.0
# 195    CTY TNHH MTV DV CÔNG ÍCH QUẬN 12        0.0
# 210    CTY TNHH VINA FOODS KYOEI               0.0
# 225    CTY TNHH IN NANU SG                     0.0
# 227    CTY TNHH MTV KIDO                       0.0
# 260    CTY TNHH MTV DV CÔNG ÍCH QUẬN 12        0.0
# 263    CTY TNHH IN NANU SG                     0.0
# 296    CTY TNHH IN NANU SG                     0.0
# 325    HÒA BÌNH 1                              2.0
# 352    CTY CP UNIBEN                           0.0
# 383    CTY TNHH IN NANU SG                     0.0
# 446    CTY CP UNIBEN                           5.0
# 468    Thuận Hòa 1                             17.0
# 482    CTY CP UNIBEN                           13.0
# 487    CÂY DA                                  20.0
# 501    BỆNH VIỆN ĐA KHOA XUYÊN Á               0.0
# 524    CTY DV Y TẾ H&H                         0.0
# 563    CTY TNHH SONG TÂN                       3.0
# 572    Nhơn Hòa 1                              13.0
# 601    Tổ 12, ấp Thượng                        21.0
# 626    CÔNG TY TNHH LOGISTIK UNICORP VIỆT NAM  0.0
# 631    ấp 7                                    18.0
# 632    CTY TNHH MTV DV CÔNG ÍCH QUẬN 12        0.0
# 679    ấp phú lợi                              20.0
# 798    Ấp 4                                    10.0
# 805    ẤP THƯỢNG                               21.0
# ...          ...                                ...
# 98211  cong ty TNHH CARIMAX SAI GON            8.0
# 98215  Lạc Chỉ                                 9.0
# 98218  LIÊN ĐOÀN LAO ĐỘNG Q.12                 0.0
# 98229  THANH TRA XD TP.HCM - H. HÓC MÔN        0.0
# 98232  THANH TRA XD TP.HCM - H. HÓC MÔN        0.0
# 98267  ấp Mũi Lớn 1                            13.0
# 98271  44/2B Đông Lân 1                        12.0
# 98300  Ấp Giữa                                 20.0
# 98305  CTY CP KỸ NGHỆ ĐÔ THÀNH                 18.0
# 98309  CTY DỊCH VỤ Y TẾ H&H                    0.0
# 98342  CTY TNHH SX-TM TOBA                     0.0
# 98352  Phước tân 2                             3.0
# 98358  LIÊN ĐOÀN LAO ĐỘNG Q.12                 0.0
# 98372  ấp chợ                                  8.0
# 98378  CTY TNHH DỆT MAY HOA SEN                5.0
# 98389  CTY TNHH VINA DUKE                      10.0
# 98406  TRƯỜNG MẦM NON HƯỚNG DƯƠNG              7.0
# 98432  CTY CP VIỆT NAM MỘC BÀI                 7.0
# 98440  Khu phố 8                               1.0
# 98446  CTY TNHH DAEWOONG VIỆT NAM              4.0
# 98449  khóm 3 phường 2                         1.0
# 98451  CƠ SỞ XÃ HỘI NHỊ XUÂN                   7.0
# 98452  Tổ 3 ấp 1                               3.0
# 98460  CTY TNHH SX-TM TOBA                     0.0
# 98464  CTY TNHH MTV THOÁT NƯỚC ĐÔ THỊ TP.HCM   11.0
# 98473  TÂN THỚI 3                              2.0
# 98480  Bốn Phú                                 10.0
# 98501  khu phố 2                               1.0
# 98509  Tân Qui Hạ                              11.0
# 98512  Cty TNHH Hansae VN                      14.0
#
#       patient_district_code patient_city_code patient_country_code
# 19     20                    79                VN
# 32     20                    79                VN
# 111    00                    79                VN
# 161    20                    79                VN
# 163    20                    79                VN
# 195    00                    79                VN
# 210    00                    79                VN
# 225    00                    79                VN
# 227    00                    79                VN
# 260    00                    79                VN
# 263    00                    79                VN
# 296    00                    79                VN
# 325    08                    80                VN
# 352    00                    79                VN
# 383    00                    79                VN
# 446    16                    79                VN
# 468    08                    80                VN
# 482    05                    51                VN
# 487    20                    79                VN
# 501    20                    79                VN
# 524    00                    79                VN
# 563    22                    79                VN
# 572    08                    80                VN
# 601    20                    79                VN
# 626    00                    79                VN
# 631    20                    79                VN
# 632    00                    79                VN
# 679    20                    79                VN
# 798    03                    70                VN
# 805    20                    79                VN
# ...    ..                    ..                ..
# 98211  20                    79                VN
# 98215  9                     54                VN
# 98218  0                     79                VN
# 98229  0                     79                VN
# 98232  0                     79                VN
# 98267  20                    79                VN
# 98271  21                    79                VN
# 98300  20                    79                VN
# 98305  20                    79                VN
# 98309  0                     79                VN
# 98342  0                     79                VN
# 98352  4                     72                VN
# 98358  0                     79                VN
# 98372  20                    79                VN
# 98378  9                     72                VN
# 98389  21                    79                VN
# 98406  21                    79                VN
# 98432  8                     72                VN
# 98440  9                     80                VN
# 98446  21                    79                VN
# 98449  7                     94                VN
# 98451  21                    79                VN
# 98452  21                    79                VN
# 98460  0                     79                VN
# 98464  21                    79                VN
# 98473  21                    79                VN
# 98480  20                    79                VN
# 98501  20                    79                VN
# 98509  8                     80                VN
# 98512  20                    79                VN
#
# [8141 rows x 10 columns]
# patient_id               category
# patient_name             category
# patient_gender           float64
# patient_occupation       category
# patient_workplace        category
# patient_street           category
# patient_ward_code        float64
# patient_district_code    category
# patient_city_code        category
# patient_country_code     category
# dtype: object

# %%
df = pd.read_csv('Clean_01_patient_id.csv')
display(df)
# Out:
#       Unnamed: 0  patient_id           patient_name  patient_gender  \
# 0     19          3960.0      TRẦN VĂN THẤN          1.0
# 1     32          455226.0    ĐỖ NGUYỄN HÀ ANH       2.0
# 2     111         489439.0    NGUYỄN THỊ THU LÀNH    2.0
# 3     161         128675.0    VÕ THỊ NGỌC ÁNH        2.0
# 4     163         52.0        LƯU VĂN ĐOÀN           1.0
# 5     195         163190.0    VŨ MINH TRÍ            1.0
# 6     210         495498.0    HÀ VĂN LONG            1.0
# 7     225         599108.0    NGUYỄN THỊ DUYÊN       2.0
# 8     227         114381.0    NGÔ VĂN LỢI            1.0
# 9     260         163191.0    NGUYỄN HOÀNG LANG      1.0
# 10    263         599109.0    NGUYỄN THANH TÒNG      1.0
# 11    296         599110.0    TRẦN VŨ LINH           1.0
# 12    325         588126.0    VÕ THỊ NHỆN            2.0
# 13    352         239678.0    ĐÀM THỊ DUYÊN          2.0
# 14    383         599111.0    TRẦN HOÀNG HẢI         1.0
# 15    446         89351.0     NGUYỄN HỮU ĐỨC         1.0
# 16    468         577034.0    PHAN THỊ BẠCH TUYẾT    2.0
# 17    482         91585.0     VÕ THỊ NHƯ THỦY        2.0
# 18    487         5523.0      PHẠM NGỌC THU HÀ       2.0
# 19    501         128678.0    NGUYỄN THỊ CẨM TÚ      2.0
# 20    524         142222.0    TẰNG KIM PHỤNG         2.0
# 21    563         384187.0    NGUYỄN THỊ TUYẾT       2.0
# 22    572         303666.0    TRẦN VĂN DẶNG          1.0
# 23    601         485847.0    TRẦN VĂN QUANG         1.0
# 24    626         489440.0    NGUYỄN THỊ MAI PHƯƠNG  2.0
# 25    631         577764.0    NGUYỄN VĂN BINH        1.0
# 26    632         163195.0    NGUYỄN HOÀNG MINH      1.0
# 27    679         610.0       HỒ VÕ NHẬT TRÂM        2.0
# 28    798         578182.0    PHẠM THỊ HỒNG HOA      2.0
# 29    805         12759.0     VÕ THỊ ÁNH TUYẾT       2.0
# ...   ...             ...                  ...       ...
# 8111  98211       115506.0    NGUYỄN THỊ KIM THẢO    2.0
# 8112  98215       582014.0    NGUYỄN THỊ HOÀNG OANH  2.0
# 8113  98218       123191.0    TÔ MINH HÒA            1.0
# 8114  98229       105440.0    TRẦN THỊ HẢO           2.0
# 8115  98232       105430.0    NGUYỄN HOÀNG ÂU        1.0
# 8116  98267       458092.0    NGUYỄN VĂN HÀO         1.0
# 8117  98271       585639.0    NGUYỄN THỊ SƯƠNG       2.0
# 8118  98300       324679.0    TRẦN XUÂN TRƯỜNG       1.0
# 8119  98305       136675.0    HUỲNH CÔNG VĂN         1.0
# 8120  98309       121142.0    PHẠM ÂN NGỌC           1.0
# 8121  98342       123425.0    NGUYỄN THỊ TUYỀN       2.0
# 8122  98352       497902.0    NGÔ THỊ MỸ             2.0
# 8123  98358       123195.0    PHAN THỊ CẨM HỒNG      2.0
# 8124  98372       174168.0    NGUYỄN PHƯƠNG NHI      2.0
# 8125  98378       27001.0     HUỲNH THỊ GÁI          2.0
# 8126  98389       54383.0     NGUYỄN THỊ CẨM         2.0
# 8127  98406       124810.0    PHẠM THỊ PHƯƠNG HẰNG   2.0
# 8128  98432       61571.0     PHAN THỊ ẢNH           2.0
# 8129  98440       558104.0    TRẦN THỊ NGUYỆT        2.0
# 8130  98446       124508.0    NGUYỄN THỊ LAN         2.0
# 8131  98449       296788.0    TẠ THỊ TUYẾT MAI       2.0
# 8132  98451       225827.0    LÊ THỊ LUYẾN           2.0
# 8133  98452       591025.0    NGUYỄN TRƯỜNG THỊNH    1.0
# 8134  98460       123429.0    PHAN NHẬT DUY          1.0
# 8135  98464       129334.0    NGUYỄN VĂN VĂN         1.0
# 8136  98473       124509.0    NGUYỄN THỊ THANH THÚY  2.0
# 8137  98480       598469.0    LÊ VĂN TÙNG            1.0
# 8138  98501       585645.0    THẠCH HOÀNG BẢO MINH   1.0
# 8139  98509       587247.0    HUỲNH THỊ NHƠN         2.0
# 8140  98512       169204.0    NGUYỄN THỊ THẢO        2.0
#
#       patient_occupation  \
# 0     13.0
# 1     2.0
# 2     13.0
# 3     13.0
# 4     13.0
# 5     13.0
# 6     13.0
# 7     13.0
# 8     13.0
# 9     13.0
# 10    13.0
# 11    13.0
# 12    3.0
# 13    13.0
# 14    13.0
# 15    13.0
# 16    4.0
# 17    4.0
# 18    13.0
# 19    13.0
# 20    13.0
# 21    4.0
# 22    99.0
# 23    99.0
# 24    13.0
# 25    3.0
# 26    13.0
# 27    13.0
# 28    99.0
# 29    13.0
# ...    ...
# 8111  13.0
# 8112  13.0
# 8113  13.0
# 8114  13.0
# 8115  13.0
# 8116  13.0
# 8117  3.0
# 8118  1.0
# 8119  13.0
# 8120  13.0
# 8121  13.0
# 8122  5.0
# 8123  13.0
# 8124  2.0
# 8125  4.0
# 8126  4.0
# 8127  15.0
# 8128  4.0
# 8129  13.0
# 8130  4.0
# 8131  4.0
# 8132  13.0
# 8133  2.0
# 8134  13.0
# 8135  13.0
# 8136  4.0
# 8137  99.0
# 8138  1.0
# 8139  3.0
# 8140  13.0
#
#                                                             patient_workplace  \
# 0     ấp Đình, Tân Phú Trung, Củ Chi
# 1     Tổ 1 ấp 1, Xã Phước Vĩnh An, Huyện Củ Chi, Thành phố Hồ Chí Minh_1.2
# 2     CÔNG TY TNHH LOGISTIK UNICORP VIỆT NAM
# 3     BỆNH VIỆN ĐA KHOA XUYÊN Á
# 4     CTY  CP TẬP ĐOÀN MAI LINH
# 5     CTY TNHH MTV DV CÔNG ÍCH QUẬN 12
# 6     CTY TNHH VINA FOODS KYOEI
# 7     CTY TNHH IN NANU SG
# 8     CTY TNHH MTV KIDO
# 9     CTY TNHH MTV DV CÔNG ÍCH QUẬN 12
# 10    CTY TNHH IN NANU SG
# 11    CTY TNHH IN NANU SG
# 12    Hòa Bình 1, Xã Hiệp Hòa, Huyện Đức Hòa, Tỉnh Long An
# 13    CTY CP UNIBEN
# 14    CTY TNHH IN NANU SG
# 15    CTY CP UNIBEN
# 16    thuận hòa 1-hòa khánh nam-đức hòa-long an_0171-40014333
# 17    CTY CP UNIBEN
# 18    Lớp 12A4,Trường THPT Tân Thông Hội
# 19    BỆNH VIỆN ĐA KHOA XUYÊN Á
# 20    CTY DV Y TẾ H&H
# 21    CTY TNHH Song Tân
# 22    Đức Hòa Thượng, Đức Hòa, Long An
# 23    Tổ 12, ấp Thượng, Xã Tân Thông Hội, Huyện Củ Chi, Thành phố Hồ Chí Minh
# 24    CÔNG TY TNHH LOGISTIK UNICORP VIỆT NAM
# 25    Xã Tân Thạnh Đông-Huyện Củ Chi_TM
# 26    CTY TNHH MTV DV CÔNG ÍCH QUẬN 12
# 27    học sinh
# 28    Xã Lộc Thái - Lộc Ninh - Bình Phước
# 29    B530,CTY TNHH MM QUÃNG VIỆT
# ...                            ...
# 8111  cong ty TNHH CARIMAX SAI GON
# 8112  Lạc Chỉ, Xã Hòa Mỹ Đông, Huyện Tây Hòa, Tỉnh Phú Yên
# 8113  LIÊN ĐOÀN LAO ĐỘNG Q.12
# 8114  THANH TRA XD TP.HCM - H. HÓC MÔN
# 8115  THANH TRA XD TP.HCM - H. HÓC MÔN
# 8116  Tân An Hội, Củ Chi, TP. Hồ Chí Minh
# 8117  44/2B Đông Lân 1, Xã Bà Điểm, Huyện Hóc Môn, Thành phố Hồ Chí Minh_8
# 8118  701351920170174
# 8119  CTY CP KỸ NGHỆ ĐÔ THÀNH
# 8120  CTY DỊCH VỤ Y TẾ H&H
# 8121  CTY TNHH SX-TM TOBA
# 8122  Phước Tân 2, Xã Phan, Huyện Dương Minh Châu, Tỉnh Tây Ninh
# 8123  LIÊN ĐOÀN LAO ĐỘNG Q.12
# 8124  Trường THPT Phú Hòa_10A6
# 8125  CTY TNHH DỆT MAY HOA SEN
# 8126  CTY TNHH VINA DUKE
# 8127  TRƯỜNG MẦM NON HƯỚNG DƯƠNG
# 8128  CTY CP VIỆT NAM MỘC BÀI
# 8129  KP 8, Thị trấn Bến Lức, Huyện Bến Lức, Tỉnh Long An
# 8130  CTY TNHH DAEWOONG VIỆT NAM
# 8131  Tân Trung, Long Tân, Ngã Năm, Sóc Trăng
# 8132  CƠ SỞ XÃ HỘI NHỊ XUÂN
# 8133  290/61 tổ 3 ấp 1, Xã Nhị Bình, Huyện Hóc Môn, Thành phố Hồ Chí Minh_9/3
# 8134  CTY TNHH SX-TM TOBA
# 8135  CTY TNHH MTV THOÁT NƯỚC ĐÔ THỊ TP.HCM
# 8136  CTY TNHH SBGEAR VINA
# 8137  Bốn Phú, Xã Trung An, Huyện Củ Chi, Thành phố Hồ Chí Minh
# 8138  701350120180165
# 8139  Tân Qui Hạ, Tân Phú, Đức Hòa, Long An (Vợ BB)
# 8140  FA3-LN9-FA3MLN6149,Cty TNHH Hansae VN
#
#                               patient_street  patient_ward_code  \
# 0     ẤP ĐÌNH                                 20.0
# 1     Tổ 1, Ấp 1                              14.0
# 2     CÔNG TY TNHH LOGISTIK UNICORP VIỆT NAM  0.0
# 3     BỆNH VIỆN ĐA KHOA XUYÊN Á               0.0
# 4     CTY  CP TẬP ĐOÀN MAI LINH               21.0
# 5     CTY TNHH MTV DV CÔNG ÍCH QUẬN 12        0.0
# 6     CTY TNHH VINA FOODS KYOEI               0.0
# 7     CTY TNHH IN NANU SG                     0.0
# 8     CTY TNHH MTV KIDO                       0.0
# 9     CTY TNHH MTV DV CÔNG ÍCH QUẬN 12        0.0
# 10    CTY TNHH IN NANU SG                     0.0
# 11    CTY TNHH IN NANU SG                     0.0
# 12    HÒA BÌNH 1                              2.0
# 13    CTY CP UNIBEN                           0.0
# 14    CTY TNHH IN NANU SG                     0.0
# 15    CTY CP UNIBEN                           5.0
# 16    Thuận Hòa 1                             17.0
# 17    CTY CP UNIBEN                           13.0
# 18    CÂY DA                                  20.0
# 19    BỆNH VIỆN ĐA KHOA XUYÊN Á               0.0
# 20    CTY DV Y TẾ H&H                         0.0
# 21    CTY TNHH SONG TÂN                       3.0
# 22    Nhơn Hòa 1                              13.0
# 23    Tổ 12, ấp Thượng                        21.0
# 24    CÔNG TY TNHH LOGISTIK UNICORP VIỆT NAM  0.0
# 25    ấp 7                                    18.0
# 26    CTY TNHH MTV DV CÔNG ÍCH QUẬN 12        0.0
# 27    ấp phú lợi                              20.0
# 28    Ấp 4                                    10.0
# 29    ẤP THƯỢNG                               21.0
# ...         ...                                ...
# 8111  cong ty TNHH CARIMAX SAI GON            8.0
# 8112  Lạc Chỉ                                 9.0
# 8113  LIÊN ĐOÀN LAO ĐỘNG Q.12                 0.0
# 8114  THANH TRA XD TP.HCM - H. HÓC MÔN        0.0
# 8115  THANH TRA XD TP.HCM - H. HÓC MÔN        0.0
# 8116  ấp Mũi Lớn 1                            13.0
# 8117  44/2B Đông Lân 1                        12.0
# 8118  Ấp Giữa                                 20.0
# 8119  CTY CP KỸ NGHỆ ĐÔ THÀNH                 18.0
# 8120  CTY DỊCH VỤ Y TẾ H&H                    0.0
# 8121  CTY TNHH SX-TM TOBA                     0.0
# 8122  Phước tân 2                             3.0
# 8123  LIÊN ĐOÀN LAO ĐỘNG Q.12                 0.0
# 8124  ấp chợ                                  8.0
# 8125  CTY TNHH DỆT MAY HOA SEN                5.0
# 8126  CTY TNHH VINA DUKE                      10.0
# 8127  TRƯỜNG MẦM NON HƯỚNG DƯƠNG              7.0
# 8128  CTY CP VIỆT NAM MỘC BÀI                 7.0
# 8129  Khu phố 8                               1.0
# 8130  CTY TNHH DAEWOONG VIỆT NAM              4.0
# 8131  khóm 3 phường 2                         1.0
# 8132  CƠ SỞ XÃ HỘI NHỊ XUÂN                   7.0
# 8133  Tổ 3 ấp 1                               3.0
# 8134  CTY TNHH SX-TM TOBA                     0.0
# 8135  CTY TNHH MTV THOÁT NƯỚC ĐÔ THỊ TP.HCM   11.0
# 8136  TÂN THỚI 3                              2.0
# 8137  Bốn Phú                                 10.0
# 8138  khu phố 2                               1.0
# 8139  Tân Qui Hạ                              11.0
# 8140  Cty TNHH Hansae VN                      14.0
#
#       patient_district_code  patient_city_code patient_country_code
# 0     20.0                   79.0               VN
# 1     20.0                   79.0               VN
# 2     0.0                    79.0               VN
# 3     20.0                   79.0               VN
# 4     20.0                   79.0               VN
# 5     0.0                    79.0               VN
# 6     0.0                    79.0               VN
# 7     0.0                    79.0               VN
# 8     0.0                    79.0               VN
# 9     0.0                    79.0               VN
# 10    0.0                    79.0               VN
# 11    0.0                    79.0               VN
# 12    8.0                    80.0               VN
# 13    0.0                    79.0               VN
# 14    0.0                    79.0               VN
# 15    16.0                   79.0               VN
# 16    8.0                    80.0               VN
# 17    5.0                    51.0               VN
# 18    20.0                   79.0               VN
# 19    20.0                   79.0               VN
# 20    0.0                    79.0               VN
# 21    22.0                   79.0               VN
# 22    8.0                    80.0               VN
# 23    20.0                   79.0               VN
# 24    0.0                    79.0               VN
# 25    20.0                   79.0               VN
# 26    0.0                    79.0               VN
# 27    20.0                   79.0               VN
# 28    3.0                    70.0               VN
# 29    20.0                   79.0               VN
# ...    ...                    ...               ..
# 8111  20.0                   79.0               VN
# 8112  9.0                    54.0               VN
# 8113  0.0                    79.0               VN
# 8114  0.0                    79.0               VN
# 8115  0.0                    79.0               VN
# 8116  20.0                   79.0               VN
# 8117  21.0                   79.0               VN
# 8118  20.0                   79.0               VN
# 8119  20.0                   79.0               VN
# 8120  0.0                    79.0               VN
# 8121  0.0                    79.0               VN
# 8122  4.0                    72.0               VN
# 8123  0.0                    79.0               VN
# 8124  20.0                   79.0               VN
# 8125  9.0                    72.0               VN
# 8126  21.0                   79.0               VN
# 8127  21.0                   79.0               VN
# 8128  8.0                    72.0               VN
# 8129  9.0                    80.0               VN
# 8130  21.0                   79.0               VN
# 8131  7.0                    94.0               VN
# 8132  21.0                   79.0               VN
# 8133  21.0                   79.0               VN
# 8134  0.0                    79.0               VN
# 8135  21.0                   79.0               VN
# 8136  21.0                   79.0               VN
# 8137  20.0                   79.0               VN
# 8138  20.0                   79.0               VN
# 8139  8.0                    80.0               VN
# 8140  20.0                   79.0               VN
#
# [8141 rows x 11 columns]
